# %% [markdown]
# Q:Load Boston data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
boston = pd.read_csv(r'C:\Users\LEKSHMI HARITHA\Desktop\AI\BostonHousings.csv')

# %%
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO  LSTAT  MEDV  CAT.MEDV
# 0       15.3   4.98  24.0         0
# 1       17.8   9.14  21.6         0
# ...

# %% [markdown]
# 1.Rename CAT.MEDV column as CAT_MEDV for easier data handling

# %%
boston.rename(columns = {'CAT.MEDV':'CAT_MEDV'}, inplace = True)
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO  LSTAT  MEDV  CAT_MEDV
# 0       15.3   4.98  24.0         0
# 1       17.8   9.14  21.6         0
# ...

# %% [markdown]
# 2.Plot MEDV vs LSAT using default settings.  Set the color of the points in the scatterplot and draw as open circles.

# %%
import matplotlib.pyplot as plt
x=boston['MEDV']
y=boston["LSTAT"]

# %%
plt.scatter(x, y)

# %% [markdown]
# 3 Find the mean of features grouped by CHAS

# %%
q=boston['CHAS']
q
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 501    0
# 502    0
# 503    0
# 504    0
# 505    0
# Name: CHAS, Length: 506, dtype: int64

# %%
m=q.mean()
m
# Out:
# 0.0691699604743083

# %% [markdown]
# 4 Draw a Barplot of Avg. MEDV grouped by CHAS using default settings. Customize

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
medv = boston['MEDV']
amedv=medv.mean()
chas = boston['CHAS']
ax.bar(chas,amedv)
plt.show()

# %% [markdown]
# Plot Histogram of MEDV

# %%
medv=boston['MEDV']
medv.hist()

# %% [markdown]
# Draw Boxplot of MEDV vs CHAS. Customize

# %%
fig = plt.figure(figsize =(7, 5)) 
data1=boston['MEDV']
data2=boston['CHAS']
data=[data1,data2]
ax = fig.add_axes([0, 0, 1, 1]) 
bp = ax.boxplot(data)

# %%
Draw Boxplots of NOX/LSTAT/PTRATIO/INDUS vs CAT_MEDV. Customize

# %%
fig = plt.figure(figsize =(7, 5)) 
data1=boston['LSTAT']
data2=boston['CAT_MEDV']
data=[data1,data2]
ax = fig.add_axes([0, 0, 1, 1]) 
bp = ax.boxplot(data)

# %% [markdown]
# Draw the Correlation Matrix of variables. Customize

# %%
boston.corr()
# Out:
#               CRIM        ZN     INDUS      CHAS       NOX        RM  \
# CRIM      1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247
# ZN       -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991
# INDUS     0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676
# CHAS     -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251
# NOX       0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188
# RM       -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000
# AGE       0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265
# DIS      -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246
# RAD       0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847
# TAX       0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048
# PTRATIO   0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501
# LSTAT     0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808
# MEDV     -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360
# ...

# %% [markdown]
# Plot NOX vs LSTAT. Color the points by the value of CAT.MEDV

# %%
x=boston['NOX']
y=boston["LSTAT"]
z=boston["CAT_MEDV"]
plt.scatter(x,y,c=z,cmap='Spectral')

# %% [markdown]
# Draw the Scatter plot Matrix with CRIM, INDUS, LSTAT, MEDV

# %%
x=boston['CRIM']
y=boston["LSTAT"]
z=boston["INDUS"]
w=boston["MEDV"]
plt.scatter(x,y,color='red')
plt.scatter(z,w,color='green')
